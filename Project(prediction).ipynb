# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'/Users/kejalgarg/Desktop/Research Paper/flight_dataset.csv')
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Date  Month  \
# 0           IndiGo  Banglore   New Delhi            0   3897    24      3
# 1        Air India   Kolkata    Banglore            2   7662     1      5
# 2      Jet Airways     Delhi      Cochin            2  13882     9      6
# 3           IndiGo   Kolkata    Banglore            1   6218    12      5
# 4           IndiGo  Banglore   New Delhi            1  13302     1      3
# ...            ...       ...         ...          ...    ...   ...    ...
# 10678     Air Asia   Kolkata    Banglore            0   4107     9      4
# 10679    Air India   Kolkata    Banglore            0   4145    27      4
# 10680  Jet Airways  Banglore       Delhi            0   7229    27      4
# 10681      Vistara  Banglore   New Delhi            0  12648     1      3
# 10682    Air India     Delhi      Cochin            2  11753     9      5
#
#        Year  Dep_hours  Dep_min  Arrival_hours  Arrival_min  Duration_hours  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Airline         10683 non-null  object
#  1   Source          10683 non-null  object
#  2   Destination     10683 non-null  object
#  3   Total_Stops     10683 non-null  int64
#  4   Price           10683 non-null  int64
#  5   Date            10683 non-null  int64
#  6   Month           10683 non-null  int64
#  7   Year            10683 non-null  int64
#  8   Dep_hours       10683 non-null  int64
#  9   Dep_min         10683 non-null  int64
#  10  Arrival_hours   10683 non-null  int64
#  11  Arrival_min     10683 non-null  int64
#  12  Duration_hours  10683 non-null  int64
#  13  Duration_min    10683 non-null  int64
# dtypes: int64(11), object(3)
# memory usage: 1.1+ MB

# %%
df.Airline.value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1752
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
df.Source.value_counts()
# Out:
# Source
# Delhi       4537
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
df.Destination.value_counts()
# Out:
# Destination
# Cochin       4537
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
df.Total_Stops.value_counts()
# Out:
# Total_Stops
# 1    5626
# 0    3491
# 2    1520
# 3      45
# 4       1
# Name: count, dtype: int64

# %%
df.Price.value_counts()
# Out:
# Price
# 10262    258
# 10844    212
# 7229     162
# 4804     160
# 4823     131
#         ...
# 14153      1
# 8488       1
# 7826       1
# 6315       1
# 12648      1
# Name: count, Length: 1870, dtype: int64

# %%
df.Price.min()
# Out:
# 1759

# %%
df.Price.max()
# Out:
# 79512

# %%
df.Price.median()
# Out:
# 8372.0

# %%
df.Month.value_counts()
# Out:
# Month
# 5    3466
# 6    3414
# 3    2724
# 4    1079
# Name: count, dtype: int64

# %%
df.drop(['Date', 'Month','Year'], axis=1, inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['Total_minutes'] = df['Duration_hours'] * 60 + df['Duration_min']
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Dep_hours  \
# 0           IndiGo  Banglore   New Delhi            0   3897         22
# 1        Air India   Kolkata    Banglore            2   7662          5
# 2      Jet Airways     Delhi      Cochin            2  13882          9
# 3           IndiGo   Kolkata    Banglore            1   6218         18
# 4           IndiGo  Banglore   New Delhi            1  13302         16
# ...            ...       ...         ...          ...    ...        ...
# 10678     Air Asia   Kolkata    Banglore            0   4107         19
# 10679    Air India   Kolkata    Banglore            0   4145         20
# 10680  Jet Airways  Banglore       Delhi            0   7229          8
# 10681      Vistara  Banglore   New Delhi            0  12648         11
# 10682    Air India     Delhi      Cochin            2  11753         10
#
#        Dep_min  Arrival_hours  Arrival_min  Duration_hours  Duration_min  \
# ...

# %%
df.Total_minutes.value_counts()
# Out:
# Total_minutes
# 170     550
# 90      386
# 175     337
# 165     337
# 155     329
#        ...
# 1710      1
# 1675      1
# 2820      1
# 1815      1
# 2860      1
# Name: count, Length: 367, dtype: int64

# %%
df.Total_minutes.min()
# Out:
# 75

# %%
df.Total_minutes.max()
# Out:
# 2860

# %%
df.Total_minutes.median()
# Out:
# 520.0

# %%
xarr=np.array(df['Price'])
yarr=np.array(df['Total_minutes'])
print(xarr)
print(yarr)
# Out:
# [ 3897  7662 13882 ...  7229 12648 11753]
# [ 170  445 1140 ...  180  160  500]

# %%
# Distribution of flight prices
plt.figure(figsize=(10, 6))
sns.histplot(df['Price'], bins=50, kde=True)
plt.title('Distribution of Flight Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Average price by airline
plt.figure(figsize=(12, 6))
sns.barplot(x='Airline', y='Price', data=df, estimator=np.mean)
plt.title('Average Price by Airline')
plt.xlabel('Airline')
plt.ylabel('Average Price')
plt.xticks(rotation=90)
plt.show()

# %%
# Average price by number of stops
plt.figure(figsize=(10, 6))
sns.barplot(x='Total_Stops', y='Price', data=df, estimator=np.mean)
plt.title('Average Price by Number of Stops')
plt.xlabel('Total Stops')
plt.ylabel('Average Price')
plt.show()

# %%
# Correlation heatmap
numeric_df = df.select_dtypes(include=[np.number])
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Preprocessing

# %%
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Dep_hours  \
# 0           IndiGo  Banglore   New Delhi            0   3897         22
# 1        Air India   Kolkata    Banglore            2   7662          5
# 2      Jet Airways     Delhi      Cochin            2  13882          9
# 3           IndiGo   Kolkata    Banglore            1   6218         18
# 4           IndiGo  Banglore   New Delhi            1  13302         16
# ...            ...       ...         ...          ...    ...        ...
# 10678     Air Asia   Kolkata    Banglore            0   4107         19
# 10679    Air India   Kolkata    Banglore            0   4145         20
# 10680  Jet Airways  Banglore       Delhi            0   7229          8
# 10681      Vistara  Banglore   New Delhi            0  12648         11
# 10682    Air India     Delhi      Cochin            2  11753         10
#
#        Dep_min  Arrival_hours  Arrival_min  Duration_hours  Duration_min  \
# ...

# %%
# Define a function to categorize the time of day
def categorize_time(hour):
    if 5 <= hour < 8:
        return 'Early Morning'
    elif 8 <= hour < 12:
        return 'Morning'
    elif 12 <= hour < 16:
        return 'Afternoon'
    elif 16 <= hour < 20:
        return 'Evening'
    else:
        return 'Night'

# Apply the function to Arrival_hours and Dep_hours columns
df['Arrival_Time_Period'] = df['Arrival_hours'].apply(categorize_time)
df['Dep_Time_Period'] = df['Dep_hours'].apply(categorize_time)

# Drop the original hours columns if you no longer need them
df.drop(['Arrival_hours', 'Dep_hours', 'Dep_min',	'Arrival_min',	'Duration_hours',	'Duration_min'	], axis=1, inplace=True)

df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Dep_min  \
# 0           IndiGo  Banglore   New Delhi            0   3897       20
# 1        Air India   Kolkata    Banglore            2   7662       50
# 2      Jet Airways     Delhi      Cochin            2  13882       25
# 3           IndiGo   Kolkata    Banglore            1   6218        5
# 4           IndiGo  Banglore   New Delhi            1  13302       50
# ...            ...       ...         ...          ...    ...      ...
# 10678     Air Asia   Kolkata    Banglore            0   4107       55
# 10679    Air India   Kolkata    Banglore            0   4145       45
# 10680  Jet Airways  Banglore       Delhi            0   7229       20
# 10681      Vistara  Banglore   New Delhi            0  12648       30
# 10682    Air India     Delhi      Cochin            2  11753       55
#
#        Arrival_min  Duration_hours  Duration_min  Total_minutes  \
# ...

# %%
df.drop(['Dep_min', 'Arrival_min','Duration_hours',	'Duration_min'], axis=1, inplace=True)
df
# Out:
#            Airline    Source Destination  Total_Stops  Price  Total_minutes  \
# 0           IndiGo  Banglore   New Delhi            0   3897            170
# 1        Air India   Kolkata    Banglore            2   7662            445
# 2      Jet Airways     Delhi      Cochin            2  13882           1140
# 3           IndiGo   Kolkata    Banglore            1   6218            325
# 4           IndiGo  Banglore   New Delhi            1  13302            285
# ...            ...       ...         ...          ...    ...            ...
# 10678     Air Asia   Kolkata    Banglore            0   4107            150
# 10679    Air India   Kolkata    Banglore            0   4145            155
# 10680  Jet Airways  Banglore       Delhi            0   7229            180
# 10681      Vistara  Banglore   New Delhi            0  12648            160
# 10682    Air India     Delhi      Cochin            2  11753            500
#
#       Arrival_Time_Period Dep_Time_Period
# ...

# %%
df.Total_Stops = pd.factorize(df.Total_Stops)[0]

# %%
df=df.join(pd.get_dummies(df.Airline, prefix='Airline')).drop('Airline', axis=1)

# %%
df=df.join(pd.get_dummies(df.Source, prefix='From')).drop('Source', axis=1)
df=df.join(pd.get_dummies(df.Destination, prefix='To')).drop('Destination', axis=1)
df=df.join(pd.get_dummies(df.Arrival_Time_Period, prefix='Arrival')).drop('Arrival_Time_Period', axis=1)
df=df.join(pd.get_dummies(df.Dep_Time_Period, prefix='Departure')).drop('Dep_Time_Period', axis=1)

# %%
df = df.astype(int)

# %%
df
# Out:
#        Total_Stops  Price  Total_minutes  Airline_Air Asia  Airline_Air India  \
# 0                0   3897            170                 0                  0
# 1                1   7662            445                 0                  1
# 2                1  13882           1140                 0                  0
# 3                2   6218            325                 0                  0
# 4                2  13302            285                 0                  0
# ...            ...    ...            ...               ...                ...
# 10678            0   4107            150                 1                  0
# 10679            0   4145            155                 0                  1
# 10680            0   7229            180                 0                  0
# 10681            0  12648            160                 0                  0
# 10682            1  11753            500                 0                  1
#
# ...

# %%
# Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
x,y = df.drop('Price',axis=1), df.Price

# %%
x_train, x_test, y_train, y_test = train_test_split (x,y,test_size=0.2)

# %%
reg = RandomForestRegressor(n_jobs=-1)
reg.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1)

# %%
reg.score(x_test, y_test)
# Out:
# 0.645156947093868

# %%
import math
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred = reg.predict(x_test)

print('R2:' , r2_score(y_test,y_pred))
print('MAE:' , mean_absolute_error(y_test,y_pred))
print('MSE:' , mean_squared_error(y_test,y_pred))
print('RMSE:' , math.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2: 0.6451569470938678
# MAE: 1624.9636435134703
# MSE: 6903683.691636381
# RMSE: 2627.4861924730226

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test,y_pred)
plt.xlabel('Actual Flight Price')
plt.ylabel('Predicted Flight Price')
plt.title('Prediction VS Actual Price')
# Out:
# Text(0.5, 1.0, 'Prediction VS Actual Price')

# %%
df.Price.describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %%
importances = dict(zip(reg.feature_names_in_,reg.feature_importances_))
sorted_importances = sorted(importances.items(), key = lambda x:x[1], reverse=True)

sorted_importances
# Out:
# [('Total_minutes', 0.6315447193130151),
#  ('Airline_Jet Airways Business', 0.09745154898430139),
#  ('Airline_Jet Airways', 0.0702354103953425),
#  ('Total_Stops', 0.028505686935092242),
#  ('To_New Delhi', 0.022427458991913108),
#  ('Airline_Multiple carriers', 0.018714573024872495),
#  ('Airline_IndiGo', 0.01408088890640176),
#  ('From_Banglore', 0.008901839735534043),
#  ('Departure_Evening', 0.008644029884023224),
#  ('Departure_Morning', 0.00853272550886181),
#  ('Arrival_Afternoon', 0.007600315980270195),
#  ('Arrival_Night', 0.0073323570014585315),
#  ('Departure_Night', 0.006871290465100172),
#  ('Arrival_Evening', 0.006634356376819087),
#  ('Departure_Afternoon', 0.006474215679251145),
#  ('To_Hyderabad', 0.006249284942506221),
#  ('From_Mumbai', 0.006014970870877126),
#  ('Arrival_Morning', 0.005929436951559428),
#  ('Departure_Early Morning', 0.005808004707648554),
#  ('Airline_Air India', 0.005209325629558925),
#  ('Arrival_Early Morning', 0.004875587940682336),
# ...

# %%
plt.figure(figsize=(10,6))
plt.bar([x[0] for x in sorted_importances[:10]],[x[1] for x in sorted_importances[:10]])
# Out:
# <BarContainer object of 10 artists>
